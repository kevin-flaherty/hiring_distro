# %% [markdown]
# # Hiring Demographics
#
# The transition between receiving a PhD and securing a tenure track faculty position is challenging for all astronomers. In the span of 3-10 years, astronomers are expected to work as postdocs at multiple institutions, often on different continents, while trying to publish multiple papers and gaining experience in advising students and/or teaching.
#
# Across many of the factors that would make a faculty candidate appealing to a hiring committe, many studies have shown a persistent bias in favor of male scientists. Men are invited to give more colloquia than women (Nittrouer et al. 2017), have a higher success rate at receiving telescope time (Lonsdale et al. 2016, Reid 2014, Patat 2016, Spekkens et al. 2018), are cited more frequently (Caplar et al. 2017), ask more questions at conferences (Schmidt & Davenport 2017, Schmidt et al. 2017, Davenport et al. 2014, Pritchard et al. 2014, Hinsley et al. 2017), are overrepresented among prestigious fellowships (Nordstrom et al. 2018), and have their abstracts rated at a higher level of scientific quality (Knobloch-Westerwick et al. 2013). These biases exist despite the lack of evidence for biological difference in science and math ability (see Giglio 2017 for a recent review). Elite male faculty in the life sciences are less likely to take on female students (Sheltzer & Smith 2014), limiting early entry points into the field, and recommendation letters show gender-based biases (Dutt et al. 2016). Female scientists that are able to navigate these effects still have to deal with high rates of sexual harassment (Clancy et al. 2014), and higher demands on their time (El-Alayli et al. 2018). These factors can lead to a female candidate appearing less qualified than an otherwise equivalent male candidate.
#
# Even among candidates with identical qualifications there is a bias against women. Moss-Racusin et al. 2012 found that identical resumes were graded differently based on the gender of the applicant; women were offered a lower salary and were less likely to be offered a position. More reservations are expressed about CVs from female faculty members (Steinpreis et al. 1999), and in hiring decisions relationship status is more often discussed, always as a negative, for female faculty candidates (Rivera 2017).
#
# Hiring biases based on race/ethinicity are also present (Gibbs et al. 2016, Betrand & Mullainathan 2004), but have been studied much less frequently in part due to the lack of a large enough sample within many STEM fields. To our knowledge no study has been done on the hiring of individuals with a non-binary gender, or of individuals who identify as LGBTQ.
#
# Biases against hiring women can change the length of time it takes to transition from getting a PhD into a tenure-track faculty position. Conversely, a push towards hiring more women, in an effort to increase the diversity of the faculty ranks, may lead to women being hired more quickly out of graduate school. Here we examine the time between when an astronomer receives a PhD and when they are hired into a tenure track faculty position, using a publicly available listing of recent faculty hires.
#
#
# **Research Question**: Are women hired more slowly or more quickly than men into tenure-track faculty postions?
#
#
# **Sample**: The sample for this study is drawn from the Astrophysics Rumor Mill (link [here](http://www.astrobetter.com/wiki/Rumor+Mill+Faculty-Staff)). This page contains a public wiki that lists various job postings within astronomy, and is updated by astronomers to indicate e.g. when phone interviews are conducted, who is on the short-list, and the name of someone that has accepted the position. This repository provides a source of information for those on the job market to search for updates on positions for which they may not have heard an official update from the search committee.
#
# For the purposes of this study, it serves as a public listing of astronomers that have recently been hired into tenure-track faculty positions (there are sections for scientific staff positions, as well as postdoral positions, but we focus on the tenure-track faculty listings for this study). For each rumor of an accepted job offer (subsequently confirmed through a Google search) we record the gender of the astronomer, the year that they were hired (taken as the year of the spring half of the hiring cycle, i.e. for someone listed on the 2014-2015 rumor mill we use 2015 as the hiring year), the year the astronomer received a PhD (based on a Google search of their CV), and whether they were hired by an R1 school or a non-R1 school. We assume a gender binary (either male or female), based on information from a Google search (e.g. a picture, gendered pronouns, etc). Data collection starts with the 2010-2011 cycle and runs through the 2016-2017 cycle. We exclude astronomers that are moving between tenure-track positions since our research question is focused on the initial hiring decision. We also exclude anyone that received a PhD before 2000, since most astronomers in this range spent a substantial amount of time working at a national lab (e.g. JPL, STSCI) before taking the tenure-track faculty position. We also focus on colleges and universities in the US since hiring practices and job descriptions can vary substantially between US and non-US institutions. Given the very small number statistics, we do not record race/ethinicity. From this list we exclude anyone for which we could not determine the gender or the year that they received their PhD. This leaves a total sample size of 245 astronomers of which 157 are men, 88 are women.
#
# While the Rumor Mill lists the vast majority of available positions in astronomer, not all of these positions have an indication of who was hired. This can occur for various reasons, such as a failed search or the person that was hired deciding not to update the rumor mill. Despite this bias we still consider this a representative, although highly incomplete, sample of astronomers hired in a given year. As discussed below, a strong gendered difference in posting to the rumor mill would be necessary to explain the observed hiring time distribution. While we cannot rule out such an effect, we have no reason to believe that it is present within the sample. The fraction of women within our sample (35$\pm$4%) is slightly larger than the fraction of female assistant professors in 2013 (26$\pm$4%, Hughes et al. 2014) suggesting that our sample is over-represented in terms of female astronomers.

# %%
# %run plot_demo

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize']=(10,6)
plot_demo(full=True)
# Out:
#
# Mean time to hiring: 4.90+-0.31

# %% [markdown]
# The above figure shows the number of astronomers hired as a function of the time between when they received their PhD and when they were hired. Over the entire distribution, the mean time to hiring is 4.90$\pm$0.31 years.
#
# In their survey of American Astronomical Society demographics, Anderson & Ivie 2013 find that among retired astronomers the median time spent in a postdoc position was two years, while among active astronomers the median time was four years. Our finding of five years between receiving a PhD and being hired into a tenure track faculty position is consistent with the trend of an increase in the amount of time astronomers are spending in temporary postdoc position.

# %%
plot_demo()
# Out:
#
# Time to faculty, Men: 5.31+-0.42
# Time to faculty, Women: 4.16+-0.44
# Prob: 0.034

# %% [markdown]
# There is a significant difference between male and female astronomers in the time between receiving a PhD and being hired into a faculty position. Women are hired on average 4.2$\pm$0.4 years out of graduate school, while men are hired on average 5.3$\pm$0.4 years out of grad school. A KS test indicates a significant difference in these distribution at p<0.05 (p=0.034). Interestingly, the number of male and female astronomers hired within the first 2 years of graduate school is identical, and is not significantly different until the fourth year out of graduate school. From this point onward, twice as many male astronomers (103) are hired into tenure track faculty positions as female astronomers (53). Note that women are over-represented in this sample, indicating that *at least* twice as many male astronomers as female astronomers are hired in years four through ten, and that *at most* the number of female astronomers hired in the first two years out of graduate school is equal to the number of male astronomers hired.

# %% [markdown]
# ## R1 vs non-R1:
#
# Small liberal arts colleges are very different from large universities in terms of resources available, relative focus of research/teaching, location, etc. and these differences may be reflected in when they hire astronomers. To examine this, we can broadly split the hiring institutions according to their Carnegie classifications into R1 (doctoral-granting, highest research activity) and non-R1 schools. Finer slicing is limited by small number statistics.
#
# Overall, 182 astronomers were hired into R1 institutions, while 63 were hired into non-R1 institutions. Of the R1 hires, 68$\pm$6% (124/182) were male, while 52$\pm$19% (33/63) of non-R1 hires were male.
#
# Comparing the hiring time, regardless of gender, we find no significant difference between R1 and non-R1 schools (shown below).

# %%
plot_cc()
# Out:
#
# Time to faculty, R1: 4.94+-0.37
# Time to faculty, non-R1: 4.78+-0.60
# Prob: 0.840

# %% [markdown]
# Interestingly, for R1 institutions there is nearly a factor of 2 drop in the number of astronomers hired 5 years out of graduate school versus 6 years out of graduate (corresponding to the last year of a second 3-year postdoc).
#
# We can split these distributions based on gender, although these results (shown below) tend to suffer from small number statistics, especially for the non-R1 distribution.

# %%
plt.rcParams['figure.figsize']=(8,7)
plot_cc(full=False)
plt.tight_layout()
# Out:
#
# Time to faculty, male R1: 5.31+-0.48
# Time to faculty, female R1: 4.14+-0.54
# Prob: 0.033
#
# Time to faculty, male non-R1: 5.30+-0.92
# Time to faculty, female non-R1: 4.20+-0.77
# Prob: 0.432

# %% [markdown]
# The R1 schools show a similar distribution, with a significant gender difference, as the full distribution. The number of female astronomers hired into tenture-track positions is equal to the number of male astronomers during the first two years out of gradutes school, but 2.6 times as many male astronomers as female astronomers are hired during years 4 through 10 (88 vs 34). This similarity to the total distribution is not surprising given that the R1 statistics make up the majority of the full distribution. The non-R1 schools suffer most strongly from small number statistics, but do show an enhancement of male astronomers hired in 8 and 9 years out of graduate school, consistent with an increase in hiring older male astronomers.

# %% [markdown]
# ## Models:
#
# There are multiple possible explanations for why the genedered distributions could differ. We examine a number of different scenarios using a hiring model, with variations based on different scenarios. The basic model consists of N$_{phd}$ people added to the labor pool each year, and each year N$_{hire}$ are randomly selected from the full labor market and 'hired' into a faculty position. The astronomers that are 'hired' are removed from the labor pool, and the model proceeds to the next year, with another N$_{phd}$ astronomers added to the labor pool and another N$_{hire}$ astronomers removed from the labor pool. Whenever someone is 'hired', the year that they were hired, along with the year they got their PhD, is recorded. The labor pool is split between male and female astronomers, depending on the specified fraction of women. Unless otherwise specified we assume that 30% of astronomers (specifically those getting a PhD and entering the tenure-track faculty market) are women.
#
# To reproduce the non-uniform hiring-time distribution we assume that the probability of being hired depends on the time since the astronomer received their phd (p$_{hire}$(t$_{phd}$)). For t$_{phd}$>10 years p$_{hire}$ is set to zero, while the probabilities for t$_{phd}$<10 are manually adjusted. In general the manual adjustement is done to reproduce the hiring time distribution for male astronomers, and the specifics of the model are adjusted to (attempt to) reproduce the female distribution. Since these models are meant to be illustrative of different scenarios, we do not e.g. perform a likelihood maximization to determine the best fit model parameters, but simply choose parameters that can reasonably reproduce the observations.
#
# The labor pool is populated starting in 1980 and runs until 2018 (the last year in which people are hired). The hiring begins in 1990, allowing enough time for the labor market to become fully populated. As with the data, we only consider people that were hired after 2010 (2011-2018). The model is started well before this date to ensure that it has reached a steady state before being compared to the data.
#
# To avoid large statistical noise in any individual trial, we use large values for N$_{phd}$ and N$_{hire}$ (N$_{phd}$=30000, N$_{hire}$=10000). While this is much larger than the actual pool of astronomers it does preserve the ratio of PhDs produced each year to tenure-track faculty openings. Mulvey & Nicholson 2014 reports ~150 PhDs awarded from 2007 to 2012, after averaging ~110 in the prior decade (see the annual AIP reports on astronomy enrollments [here](https://www.aip.org/statistics/rosters/astronomy)), while in the Astrophysics Rumor Mill there are roughly 50 tenure-track faculty positions listed each year.
#
#
# Below we demonstrate a basic model that reproduces the full distribution of hiring times. Here, instead of the total number of people hired per year, we show the fraction of astronomers hired per year in order to directly compare the data (shown in black) with the model (shown in red). This normalization is done separately for both male and female astronomers, and the $success$ array contains the relative probabilities of being hired in a given year after receiving a PhD.

# %%
plt.rcParams['figure.figsize']=(10,6)
basic_model(success=[.01,.04,.18,.33,.43,.56,.44,.36,.27,.1])
plt.title('Full Distribution',fontsize=24)
# Out:
#
# Mean time to hiring: 4.90+-0.31
#
# Mean time to hiring (model): 4.71
# /anaconda2/lib/python2.7/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# Text(0.5,1,'Full Distribution')

# %%
basic_model(success=[.02,.04,.16,.31,.47,.61,.49,.43,.41,.15],male_only=True)
plt.title('Male Astronomers',fontsize=24)
# Out:
#
# Mean time to hiring: 5.31+-0.42
#
# Mean time to hiring (model): 4.94
# Text(0.5,1,'Male Astronomers')

# %%
basic_model(success=[.02,.07,.24,.45,.5,.6,.42,.31,.09,.00],female_only=True)
plt.title('Female Astronomers',fontsize=24)
# Out:
#
# Mean time to hiring: 4.16+-0.44
#
# Mean time to hiring (model): 4.12
# Text(0.5,1,'Female Astronomers')

# %% [markdown]
# ## Gendered Models
#
# We next turn to explaining the difference in the distributions between men and women. We consider a number of different methods to bias the distributions:
# - Increase in the number of women with time.
# - A higher probability of a female astronomer being hired than a male astronomer.
# - Women leaving the labor pool more quickly than men.
# - A bias against hiring women that received a PhD more than four years ago.
#
# To fit the data, we adjust the $success$ array until it reproduces the male hiring time distribution, and then adjust the model parameters until the model best reproduces the female hiring time distribution. As with the basic model, we only consider the relative fraction of astronomers hired in a given year, with separate normalizations for the male and female distributions.
#
# To understand if our model preserves the general demographics of the labor market, we also use our models to predict the fraction of female PhD students in 2003 and assistant professors in 2013 (Hughes et al. 2014) and the fraction of women applying to faculty positions in 2014 (Thompson 2015). Based on their demographics survey, Hughes et al. 2013 compare the fraction of female graduate students in 2003 to the fraction of female assistant professors in 2013. Assuming no attrition of women from the labor market, these two fractions would be the same, but instead there is a significant decrease from 30$\pm$2% in 2003 to 26$\pm$4% in 2013. This may be a reflection of the same process that is created the distinct hiring time distributions for male and female astronomers.
#
# To calculate the number of female PhD students in 2003, we count all entries that received a PhD between 2003 and 2010 and calculate the fraction of women within this subset. Assuming a typical PhD length of 7 years, this range of times encompases first year and recently graduated students within the model. To calculate the fraction of female assistant professors in 2013, we calculate the fraction of women among astronomers hired between 2007 and 2013. This assumes a typical time to tenure (and promotion from assistant to associate faculty) of six years.
#
# Thompson (2015), in a survey of 30 astronomy departments across the country, find that women make up 19$\pm$3% of the applicant pool for tenure track faculty positions. To compare with this finding, we calculate the fraction of women within the labor pool in 2014.

# %% [markdown]
# ### Model 1: Changing Demographics
#
# The first model we consider is one in which the fraction of women within astronomy increases with time. Between 1992 and 2013 the fraction of female graduate students rose from 22% to 34%, while the fraction of female assistant professors increased from 17% to 26% over the same period (Hughes et al. 2014). Adding substantially more young women to the labor pool will bias the hiring distribution towards shorter times given that there are simply more women available to be hired.
#
# We model the change in the fraction of women getting PhDs as a logistic function (f$_{phd}$(female) = 1/(1+exp(-slope$*$(year-year0)) where $slope$ represents the rate of increase in women, while $year0$ is the year in which gender parity is reached among PhDs. To best fit the demographics survey of Hughes et al. 2014, we use a $slope$ of .027 and $year0$ of 2040. This is shown below, with the lines representing the model and the points representing the measurements of Hughes et al.

# %%
plot_female_increase(.027,year0=2040)
plt.tight_layout()

# %% [markdown]
# The figures below show the hiring time for men and women accounting for the changing demographics. Here we show the fraction of male/female astronomers hired in a given year, with the data shown in black and the model shown in red.
#
# This model does not recover the distribution of hiring times for women, and instead predicts more women hired at later times. It also slightly overpredicts the fraction of female assistant professors in 2013 (28% for the model vs 26% from the data), and the fraction of women within the labor market (24% for the model vs. 19% from the data). This indicates that changing demographics within the field are not the source of the different hiring time distributions.

# %%
plt.rcParams['figure.figsize']=(8,7)
gendered_model1([.02,.06,.21,.38,.54,.61,.45,.36,.32,.11],slope=.027,year0=2040)
plt.tight_layout()
# Out:
# %Female 2003 grad students (30pm2%): 0.29
# %Female labor market 2014 (19pm3%): 0.24
# %Female Assistant Prof 2013 (26pm4%): 0.28

# %% [markdown]
# ## Model 2: Hiring Bias
#
# Our second model considers an intrinsic bias towards hiring women. This may occur as a result of diversity efforts leading more colleges and universities to hire women more quickly out of graduate school, or because women are intrinsically better qualified for faculty jobs and therefore are more successful on the job market. Given the finite number of women that receive a PhD each year, by removing women from the labor pool early on there are fewer women at later times, shifting the peak of hiring distribution towards shorter timescales.
#
# We model this by including a *bias* parameter that is the multiplicative increase in the probability of hiring a women relative to hiring a man (e.g *bias*=2 indicates that a female astronomer is twice as likely to be hired as a male astronomer).

# %%
gendered_model2([.02,.05,.21,.4,.55,.63,.45,.34,.32,.12],bias=10)
plt.tight_layout()
# Out:
# %Female 2003 grad students (30pm2%): 0.30
# %Female labor market 2014 (19pm3%): 0.18
# %Female Assistant Prof 2013 (26pm4%): 0.70

# %% [markdown]
# An extreme bias (10x higher probability of hiring a female astronomer than hiring a male astronomer) is needed to approximatly reproduce the hiring time distribution for women. This clearly contradicts the fraction of female assistant professors, over-predicting the 2013 value by a factor of 2.
#
# The need for a strong bias in this scenario is because the number of PhDs produced each year outnumbers the number of tenure track faculty jobs, and it takes a strong bias to substantially deplete the female labor pool. While the number of astronomers that enter the labor pool each year (30,000) and the number that are hired (10,000) with our model is much, much larger than the actual statistics, the relative proportion is realistic. According to the AIP, ~150 astronomers received PhDs per year between 2007 and 2012 (Mulvey & Nicholson 2012), while there are typically ~50 faculty job postings per year.
#
# A much more labor-starved market can reproduce the male/female hiring time distributions (shown below) with a more modest bias towards women. Here we consider 25000 astronomers hired each year into tenure track faculty jobs, with a 2x higher probablity of a female candidate being hired than a male candidate. While this can reproduce the female hiring time distribution, it would require that there are ~125 tenure track faculty positions in astronomy each year, which is certainly not true. This model also still over-predicts the fraction of female assistant professors in 2013.

# %%
gendered_model2([.01,.04,.14,.28,.45,.63,.53,.48,.5,.19],bias=2,Nhire=25000)
plt.tight_layout()
# Out:
# %Female 2003 grad students (30pm2%): 0.30
# %Female labor market 2014 (19pm3%): 0.22
# %Female Assistant Prof 2013 (26pm4%): 0.34

# %% [markdown]
# ## Model 3: Leaving the Labor Pool
#
# The third model we consider is one in which astronomers leave the labor pool at a rate that increases with time. As is obvious to anyone that has gone through the process, applying to faculty jobs year after year can become demoralizing,  which can drive people away from faculty jobs. Some of the astronomers that leave the faculty labor market leave the field entirely, while some of head into non-academic jobs, either at national research institutions (STSCI, etc), or outside of the field of astronomy. If women leave the labor market at a higher rate than men do, then this would starve the long timescale end of the distribution, leading to a sharper turnover in the hiring time distribution for women.
#
# The probability of leaving is specified by an exponential with a characteristic timescale *$\tau$* (*p_{leave}$ = 1-exp(time-2)/$\tau$ *), where *time* is the numbers of years since receiving a PhD. A smaller timescale implies that the probability of being removed from the labor market increases quickly with time since PhD. We assume that the timescale differs between male and female astronomers, with shorter timescale (e.g. more rapid departure from the labor market) for women. This departure from the labor market is assumed to only start 2 years after receiving a PhD. Based on this probability, astronomers are removed from the labor market and are not available to be hired.

# %%
gendered_model3([.01,.06,.21,.40,.59,.76,.62,.59,.65,.31],tau_male=40.,tau_female=10.)
plt.tight_layout()
# Out:
# %Female 2003 grad students (30pm2%): 0.30
# %Female labor market 2014 (19pm3%): 0.18
# %Female Assistant Prof 2013 (26pm4%): 0.24

# %% [markdown]
# This model provides a reasonable match to the female hiring time distribution, matches the number of women in the labor market, but slightly under-predicts the fraction of female assistant professors in 2013.
#
# Within this model women leave the field at a rate that is roughly ~3-4 times higher than that of men (shown below). We caution that this model is not unique, nor is it likely to be the best fit. It is merely illustrative of one type of change in the labor market that is consistent with the data. In the figure below, the top panel shows the fraction of astronomers from each gender that leave the faculty labor market each year. The bottom panel is the ratio of these two departure rates. Note that the number of women in the labor market is about 1/3rd of that of men; according to our model roughly an equal number of male and female astronomers leave the labor market each year, but for women this makes up a larger fraction of the female labor market.

# %%
plot_df(40.,10.)
plt.tight_layout()

# %% [markdown]
# ### Model 3b: Changing Demographics + Leaving the Labor Market
#
# Counteracting the departure of female astronomers from the labor market is the increase in the fraction of women receiving PhDs. We can include both of these effects, incorporating the change in PhD demographics as described earlier into the model where astronomers leave the labor market after a certain period of time.

# %%
gendered_model3b([.01,.06,.21,.40,.59,.76,.62,.59,.65,.31],tau_male=40.,tau_female=10.,slope=.027,year0=2040)
plt.tight_layout()
# Out:
# %Female 2003 grad students (30pm2%): 0.29
# %Female labor market 2014 (19pm3%): 0.16
# %Female Assistant Prof 2013 (26pm4%): 0.22

# %% [markdown]
# As before, the change in the gender demographics is not strong enough to substantially change the hiring time distribution.

# %% [markdown]
# ### Model 3c: Long Term effects of changing demographics and leaving the labor market
#
# This model can be extended beyond the age range considered here to predict the fraction of graduate students and assistant professors in the future, as well as the current fraction of female associate and full professors based on past graduate school demographics. With these predictions we can then look for any significant departures from academia by female astronomers in faculty positions.
#
# The fraction of women in associate/full professor positions has been steadily increasing with time, with Hughes et al. 2014 finding that women make up 17%, 18%, 20%, and 26% of associate professors in 1992, 1999, 2003, and 2013 respectively, while women make up 5%, 7%, 9%, and 14% of full professors over the same period. These numbers are comparable to the demographics survey of Ivie et al. 2013.
#
# To calculate the fraction of female associate and full professors within our model we expand the model to start populating the labor market in 1940, with hiring beginning in 1950, with an end date of 2050. Associate professors are those astronomers that were hired between 6 and 15 years prior to the given date, while full professors were hired between 15 and 35 years in the past. These ranges are consistent with the average time since earning a PhD for full and associate professors as reported by Ivie & Ray 2005.
#
# To better approximate the historical fraction of women receiving PhDs in astronomy we switch from a logistic function to describe the fraction of women earning PhDs to a power law model (f$\sim$year$^2$). Ivie & Ray 2005 report that in the 70s and 80s roughly 7% of astronomy PhDs were awarded to women rising to ~17% in 1990. Between 1920 and 1950 the fraction of physics PhDs earned by women is roughly constant at ~5%, prior to decreasing to ~2% in the 50s and 60s (Ivie & Ray 2005). Among astronomers that earned a PhD between 1969 and 1981, 7% were female, 1982-1990 were 13% female, and 1993-1998 19% were female (Ivie & Ray 2005), as indicated by the horizontal red lines below. Our logistic model predicts ~10-20% of PhDs between 1970 and 1980 were awarded to women, which over-predicts the actual fraction of women. As shown below the power law model is more effective at reproducing the rise in female astronomers over the past half century.

# %%
plot_exp_demo(tau=270.)
plt.tight_layout()
# Out:
# %Female 1992 grad students (22%): 0.20
# %Female 2003 grad students (26%): 0.25
# %Female 2003 grad students (30%): 0.28
# %Female 2003 grad students (34%): 0.37
# %Female 2040 grad students (??%): 0.68
# %Female 1969-1981 grad students (7%): 0.08
# %Female 1982-1990 grad students (13%): 0.14
# %Female 1993-1998 grad students (19%): 0.20

# %%
gendered_model3c([.01,.06,.21,.40,.59,.76,.62,.59,.65,.31],tau_male=40.,tau_female=10.,tau=270.)
plt.tight_layout()
# Out:
# %Female 1992 grad students (22%): 0.20
# %Female 2003 grad students (26%): 0.25
# %Female 2003 grad students (30%): 0.28
# %Female 2003 grad students (34%): 0.37
# %Female 2040 grad students (??%): 0.68
# %Female 1969-1981 grad students (7%): 0.08
# %Female 1982-1990 grad students (13%): 0.14
# %Female 1993-1998 grad students (19%): 0.20
#
# %Female Assistant Prof 1992 (17%): 0.10
# %Female Assistant Prof 1999 (18%): 0.13
# %Female Assistant Prof 2003 (20%): 0.15
# %Female Assistant Prof 2013 (26%): 0.22
# %Female Assistant Prof 2040 (??%): 0.47
#
# %Female Associate Prof 1992 (10%): 0.07
# %Female Associate Prof 1999 (14%): 0.09
# %Female Associate Prof 2003 (21%): 0.11
# %Female Associate Prof 2013 (19%): 0.17
# %Female Associate Prof 2040 (??%): 0.39
#
# %Female Full Prof 1992 (5%): 0.03
# %Female Full Prof 1999 (7%): 0.04
# %Female Full Prof 2003 (9%): 0.06
# %Female Full Prof 2013 (14%): 0.09
# %Female Full Prof 2040 (??%): 0.26

# %% [markdown]
# In the figure above we compare the fraction of female graduate students, assistant professors, associate professors, and full professors as measured by Hughes et al. 2014 (filled circles) with the predicted fractions from our model (dashed lines) We are able to reproduce the fraction of women among graduate students, and slightly under-predict the fraction of female assistant, associate, and full professors. This suggests that there isn't a significant departure of women from academia after being hired into faculty positions.
#
# While we do not find that women are leaving academia in larger numbers, we can not rule out small changes in the fraction of women (at the ~5-10% level), and this does not imply that women experience a positive and supportive culture within academia. The magnitude of the negative actions required to drive someone out of academia and into a new career trajectory when they are in their 40s-60s is substantial, and many minor negative effects can still be present. (e.g. El-Alayli et al. 2018)

# %% [markdown]
# ### Model 3e: Leaving the field, with initial departure
#
# Within our model of astronomers leaving the field, we assume that all astronomers that receive a PhD are in the faculty labor market the first two years out of graduate school. This is certainly not true; a significant number of astronomers leave the field immediately upon receiving a PhD. Here we consider such an effect on the hiring time distribution. To accomplish this we introduce a simple correction to the above model. Instead of employing a floor at $f_{leave}$=0, we use a floor of $df_{male}$ for male astronomers and $df_{female}$ for female astronomers.
#
# This demostrates some of the degeneracies in our model. First we consider an initial difference in the fraction of male/female astronomers that leave, but with the same long time behavior

# %%
gendered_model3e([.01,.05,.15,.35,.55,.78,.7,.73,.83,.4],tau_male=40.,tau_female=40.,df_male=.1,df_female=.3)
plt.tight_layout()
# Out:
# %Female 2003 grad students (30pm2%): 0.30
# %Female labor market 2014 (19pm3%): 0.20
# %Female Assistant Prof 2013 (26pm4%): 0.18

# %%
plot_df(40,40,.1,.3)
plt.ylim(0,.4)
plt.tight_layout()

# %% [markdown]
# A higher baseline rate of women leaving the faculty labor market, when compensated with less departure at later times, can match the hiring time distribution. This model does underpredict the fraction of female assistant professors in 2013 (18% vs 26$\pm$4%). Further fine-tuning may be necessary to find a more realistic model.
#
# Similarly we can remove the increase in departure with time, and assume a constant fraction of male/female astronomers leaving the faculty labor market each year. We can examine this by setting $\tau_{male}$ and $\tau_{female}$ to very large values (10$^6$) while setting $df_{male}$ and $df_{female}$ to non-zero values.

# %%
gendered_model3e([.01,.06,.23,.45,.66,.78,.64,.54,.50,.22],tau_male=1e6,tau_female=1e6,df_male=.05,df_female=.20)
plt.tight_layout()
# Out:
# %Female 2003 grad students (30pm2%): 0.30
# %Female labor market 2014 (19pm3%): 0.19
# %Female Assistant Prof 2013 (26pm4%): 0.22

# %% [markdown]
# Again, if the rate at which women leave the faculty labor market is higher than for men, we can match the hiring time distribution. In this model 5% of every male astronomers leave in every year our of graduate school (i.e. 5% of male astronomers one year out of graduate leave the faculty labor market, 5% of male astronomers in their second year leave the faculty labor market, etc.), while 20% of female astronomers leave in every year out of graduate school. The cumulative effect of all of these departures is that only 40% of male astronomers, and 89% of female astronomers, leave the faculty job market by year 10.
#
# Both of the above models highlight some of the degeneracies in our model. These two models, along with the original Model 3, are slightly different and are still able to reproduce the hiring time distribution for female astronomers, and provide a reasonable match to the fraction of female assistant professors in 2014, and the fraction of women within the labor market in 2014. The commonality among all of these models is the increased rate at which women leave the labor market compared to men.

# %% [markdown]
# ## Model 4: Changing hiring probability with time since PhD
#
# The best fit model is one in which female astronomers leave the tenure track labor market, with the probability of leaving increasing with time since receiving a PhD. A potentially similar possibility is that there is a bias against hiring female astronomers, and that this bias increases in time since the candidate received a PhD.
#
# To model this, we apply a multiplicative factor on the hiring probability as a function of age. This multiplicative factor is specified by an exponential decrease with time, with a characteristic timescale $\tau$ (prob $\sim$ exp(-dt/$\tau$)). This factor is shown below for three different timescales. For $tau$=1 year, the probability of being hired in 10% as large for a female astronomer as for a male astronomer.

# %%
import numpy as np
year = np.arange(10)
tau = np.array([1.,3.,10.])
for t in tau:
    plt.plot(year,np.exp(-year/t),lw=3)
plt.legend((r'$\tau$ = 1',r'$\tau$ = 3',r'$\tau$ = 10'),frameon=False,loc='best',fontsize=16)
plt.xlabel('Time to hiring (years)',fontsize=16,fontweight='bold')
plt.tight_layout()

# %%
gendered_model5([.01,.06,.2,.36,.51,.63,.5,.41,.38,.11],tau=4.)
plt.tight_layout()
# Out:
# %Female 2003 grad students (30pm2%): 0.30
# %Female labor market 2014 (19pm3%): 0.35
# %Female Assistant Prof 2013 (26pm4%): 0.14

# %% [markdown]
# With $\tau$=4 years this model reproduces the hiring time distribution for female astronomers, but this model fails to reproduce the demographics. It overpredicts the fraction of women in the labor market (35% vs 19$\pm$3%) and under-predicts the fraction of female assistant professors (13% vs 26$\pm$4%). This is not surprising since it introduces a biased against hiring female astronomers, which decreases their presence among faculty members, while leaving them in the labor market.

# %% [markdown]
# ## Conclusions
#
# Moving from a PhD into a tenure-track faculty position is a difficult career transition for many scientists. Here we have examined the time for this transition to occur, by examining astronomers listed on the Astrophysics Faculty Rumor Mill. We find that on average it takes 5 years for an astronomer to be hired into a faculty position. We also find that there is a significant different between the distribution of hiring times between male and female astronomers. Female astronomers are hired (at most) at the same rate as male astronomers during the first two years out of graduate school, but from years 4 through 10 (at least) twice as many male astronomers as female astronomers are hired into faculty positions. This disparaty is seen mainly for R1 schools, which make up the majority of our sample, but hints of the gendered difference are seen among non-R1 schools as well.
#
# We consider a number of models to try and better understand the source of this difference. We find that the difference in the hiring time distribution cannot be explained by the increase in female astronomers with time, by a bias toward hiring women into faculty position, or a bias against hiring female astronomers that have been out of graduate school for more than four years.
#
# The most promising model is one in which female astronomers leave the faculty labor market at a rate that increases with time, and is ~3 times hire for female astronomers than for male astronomers. This model is able to reproduce the distribution of hiring times for female astronomers, and is consistent with the fraction of female assistant professors in 2013, and the fraction of female astronomers applying for faculty jobs in 2014.
#
# This model is consistent with the narrative of a leaky pipeline, in which some fraction of female astronomers leave the field at every step from undergraduate->graduate->postdoc->faculty. The hiring time distribution suggests that, during the postdoc years, most of the 'leakiness' occurs >4 years after receiving a PhD, coincident with the second (or third) 3-year postdoc position.
#
# In studying the transition from receiving a PhD into a faculty position we have only considered one possible career path, and do not intend to imply that faculty jobs are the 'ideal' career path for anyone with a PhD in astronomy.

# %% [markdown]
# ### References
#
# - Anderson & Ivie 2013, AAS Demographic Survey https://aas.org/files/resources/aas_members_workforce_survey_final_jan2014v2.pdf
# - Bertrand & Mullainathan 2004 https://www.povertyactionlab.org/sites/default/files/publications/3%20A%20Field%20Experiment%20on%20Labor%20Market%20Discrimination%20Sep%2004.pdf
# - Caplar, Tacchella, Birrer 2017, Nature Astronomy https://arxiv.org/abs/1610.08984
# - Clancy et al. 2014, PLOS One http://journals.plos.org/plosone/article?id=10.1371/journal.pone.0102172
# - Davenport et al. 2014, arXiv:1403.3091 https://arxiv.org/abs/1403.3091
# - Dutt et al. 2016, Nature Geosciences https://www.nature.com/articles/ngeo2819
# - El-Alayli, Hansen-Brown, Ceynar 2018, Sex Roles https://link.springer.com/article/10.1007%2Fs11199-017-0872-6
# - Gibbs et al. 2016, eLIFE https://elifesciences.org/articles/21393
# - Giglio 2017, https://medium.com/@tweetingmouse/the-truth-has-got-its-boots-on-what-the-evidence-says-about-mr-damores-google-memo-bc93c8b2fdb9
# - Hinsley et al. 2017, PLOS One, http://journals.plos.org/plosone/article?id=10.1371/journal.pone.0185534
# - Hughes et al. 2014: Jan 2014 STATUS Newsletter, https://cswa.aas.org/status/Status_2014_Jan.pdf, ed: N. Morrison
# - Ivie & Ray 2005: Feb 2005, AIP Newsletter, https://www.aip.org/sites/default/files/statistics/women/women-pa-05.pdf
# - Ivie et al. 2013: Aug 2013 AIP Newsletter, https://www.aip.org/sites/default/files/statistics/faculty/womenfac-pa-10.pdf
# - Knobloch-Westerwick et al. 2013, Science Communication, http://journals.sagepub.com/doi/abs/10.1177/1075547012472684
# - Lonsdale, Schwab, & Hunt 2016 arXiv:1611.04795 https://arxiv.org/abs/1611.04795
# - Moss-Racusin et al. 2014, PNAS http://www.pnas.org/content/109/41/16474
# - Mulvey & Nicholson 2014: AIP https://www.aip.org/sites/default/files/statistics/undergrad/enrolldegrees-a-12.3.pdf
# - Nittrouer, et al. 2017 PNAS http://www.pnas.org/content/early/2017/12/12/1708414115
# - Nordstrom, et al. 2018, APS https://www.aps.org/publications/apsnews/201804/backpage.cfm
# - Patat 2016 arXiv:1610.00920 https://arxiv.org/abs/1610.00920
# - Pritchard et al. 2014, arXiv:1412.4571 https://arxiv.org/abs/1412.4571
# - Reid 2014 arXiv:1409.3528 https://arxiv.org/abs/1409.3528
# - Rivera 2017, American Sociological Review http://journals.sagepub.com/doi/abs/10.1177/0003122417739294?journalCode=asra&
# - Schmidt & Davenport 2017 arXiv:1708.02775 https://arxiv.org/abs/1708.02775
# - Schmidt et al. 2017 arXiv:1704.05260 https://arxiv.org/abs/1704.05260
# - Sheltzer & Smith 2014, PNAS, http://www.pnas.org/content/111/28/10107
# - Spekkens et al. 2018 arXiv:1805.06508 https://arxiv.org/abs/1805.06508v1
# - Steinpreis, Anders, & Ritzke 1999, Sex Roles https://link.springer.com/article/10.1023/A:1018839203698
